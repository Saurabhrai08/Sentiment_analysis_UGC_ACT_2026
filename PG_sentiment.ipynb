    "https://navbharattimes.indiatimes.com/metro/mumbai/politics/ugc-bill-20226-hindi-news-ugc-kanoon-se-upper-caste-ko-kya-hai-khatara-explained-why-its-being-opposed-all/articleshow/127560675.cms",
    "https://www.bhaskar.com/national/news/ugc-new-rules-protest-delhi-up-tamil-nadu-cm-stalin-backs-reforms-137069523.html",
    "https://www.esakal.com/education-jobs/ugc-rules-controversy-3c-vs-3e-difference-impact-universities-students-mms21",
    "https://www.abplive.com/education/what-are-the-ugc-equity-regulations-2026-guideline-why-are-they-controversial-3078794",
    "https://www.hindustantimes.com/india-news/protests-plea-in-supreme-court-amid-row-over-ugc-rules-new-regulations-decoded-101769561146269.html",
    "https://www.hindustantimes.com/india-news/protests-plea-in-supreme-court-amid-row-over-ugc-rules-new-regulations-decoded-101769561146269.html",
    "https://www.navakal.in/desh-videsh/ugc-new-anti-discrimination-rules-2026-obc-inclusion-controversy-details/",
    "https://divyamarathi.bhaskar.com/dvm-originals/news/ugc-rules-2026-protest-caste-discrimination-guideline-controversy-ur-vs-obc-sc-st-137031767.html",
    "https://www.loksatta.com/sampadkiya/columns/university-students-protest-against-new-ugc-regulations-zws-70-5677040/",
    "https://divyamarathi.bhaskar.com/dvm-originals/news/ugc-rules-2026-caste-discrimination-controversy-students-protest-bjp-sc-137085297.html",
    "https://www.jagran.com/delhi/new-delhi-city-ugc-rules-protest-in-delhi-demonstrators-detained-40165443.html",
    "https://www.abplive.com/states/delhi-ncr/delhi-university-student-union-aisa-protest-to-implement-ugc-act-2026-3084143",
    "https://news.abplive.com/education/ugc-regulation-2026-sparks-student-protest-call-in-delhi-rules-will-create-chaos-on-campuses-1823948",
    "https://www.livehindustan.com/national/ugc-new-equity-regulations-2026-controversy-live-updates-protests-live-blog-201769561499476-2.html",
    "https://eduvarta.com/North-India-is-facing-chaos-due-to-new-UGC-laws",
    "https://marathi.freepressjournal.in/nation/ugc-new-rules-protests-india-supreme-court-hearing",
    "https://www.tv9hindi.com/videos/kumar-vishwas-leads-savarn-protest-against-ugcs-new-regulations-amidst-delhi-uproar-3664327.html",
    "https://www.timesnowhindi.com/india/ugc-bill-2026-controversy-equality-rules-protest-india-article-153512281",
    "https://www.aajtak.in/explained/story/ugc-new-rules-2026-controversy-and-student-protests-in-higher-education-ntcpvp-dskc-2450638-2026-01-28",
    "https://www.hindustantimes.com/education/news/delhi-university-students-protest-against-new-ugc-regulations-101769654194380.html",
    "https://www.navarashtra.com/india/ugc-rules-controversy-protest-in-delhi-bjp-leaders-resign-news-marathi-1125380.html"









]

# %%
def detect_language(text):
    try:
        return detect(text)
    except:
        return "unknown"

# %%
def translate_text(text):
    try:
        return GoogleTranslator(source='auto', target='en').translate(text)
    except:
        return text

# %%
def scrape_article(url):

    headers = {"User-Agent": "Mozilla/5.0"}

    try:
        response = requests.get(url, headers=headers, timeout=10)

        if response.status_code != 200:
            print("Failed:", url)
            return []

        soup = BeautifulSoup(response.text, "html.parser")

        rows = []

        for p in soup.find_all("p"):

            text = p.get_text().strip()

            if len(text) > 40:

                lang = detect_language(text)

                # Only required languages
                if lang in ['en', 'hi', 'ta', 'bn', 'mr']:

                    translated = translate_text(text)

                    rows.append({
                        "Source": url.split("/")[2],
                        "Original_Text": text,
                        "Translated_Text": translated,
                        "Language": lang,
                        "URL": url
                    })

        return rows

    except Exception as e:
        print("Error:", url, e)
        return []

# %%
dataset = []

for i, url in enumerate(urls):

    print(f"{i+1}. Scraping:", url)

    article_rows = scrape_article(url)

    dataset.extend(article_rows)

    print("Paragraphs:", len(article_rows))

    time.sleep(2)  # avoid blocking
# Out:
# 1. Scraping: https://www.ugc.gov.in/regulations
# Failed: https://www.ugc.gov.in/regulations
# Paragraphs: 0
# 2. Scraping: https://rcm.ac.in/what-is-ugc-act-2026/
# Paragraphs: 41
# 3. Scraping: https://www.pmfias.com/ugc-anti-discrimination-regulations/
# Paragraphs: 9
# 4. Scraping: https://indianexpress.com/article/explained/ugc-new-regulation-controversy-10496730/
# Paragraphs: 35
# 5. Scraping: https://indianexpress.com/article/explained/ugc-equity-guidelines-2012-2026-10502081/
# Paragraphs: 21
# 6. Scraping: https://www.newindianexpress.com/nation/2026/Jan/29/explainer-how-the-new-ugc-equity-regulations-reshape-campus-anti-discrimination-rules
# Paragraphs: 13
# 7. Scraping: https://www.livelaw.in/articles/ugc-regulations-2026-examining-equity-522470
# Paragraphs: 32
# 8. Scraping: https://economictimes.indiatimes.com/news/new-updates/ugc-new-rules-in-place-to-stop-caste-based-discrimination-check-new-guidelines-how-to-file-complaints-other-details/articleshow/127092418.cms
# ...

# %%
df = pd.DataFrame(dataset)

print("Total Rows:", len(df))
print("Columns:", df.columns)

df.head()
# Out:
# Total Rows: 4417
# Columns: Index(['Source', 'Original_Text', 'Translated_Text', 'Language', 'URL'], dtype='object')
#       Source                                      Original_Text  \
# 0  rcm.ac.in    Copyright © 2026 Regional College Of Management
# 1  rcm.ac.in  Home > blogs > ugc act 2026 > What is UGC Act ...
# 2  rcm.ac.in  The UGC Act 2026 has become one of the most di...
# 3  rcm.ac.in  Let’s break down the UGC meaning, UGC law, UGC...
# 4  rcm.ac.in  The term UGC Act 2026 refers to the University...
#
#                                      Translated_Text Language  \
# 0    Copyright © 2026 Regional College Of Management       en
# 1  Home > blogs > ugc act 2026 > What is UGC Act ...       en
# 2  The UGC Act 2026 has become one of the most di...       en
# 3  Let’s break down the UGC meaning, UGC law, UGC...       en
# 4  The term UGC Act 2026 refers to the University...       en
#
#                                        URL
# 0  https://rcm.ac.in/what-is-ugc-act-2026/
# ...

# %%
df = df.drop_duplicates(subset=["Translated_Text"])

print("After removing duplicates:", len(df))
# Out:
# After removing duplicates: 3770

# %%
print(df['Language'].value_counts())
# Out:
# Language
# en    2176
# ta     624
# hi     481
# mr     253
# bn     236
# Name: count, dtype: int64

# %%
df.to_csv("multilingual_translated_dataset.csv", index=False)

print("Dataset saved successfully!")
# Out:
# Dataset saved successfully!

# %%
# !pip install nltk scikit-learn imbalanced-learn

# %%
import pandas as pd
import re
import nltk

nltk.download('stopwords')
nltk.download('vader_lexicon')

from nltk.corpus import stopwords
from nltk.sentiment import SentimentIntensityAnalyzer

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

from imblearn.over_sampling import RandomOverSampler
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
df = pd.read_csv("multilingual_translated_dataset.csv")

print("Rows:", len(df))
df.head()
# Out:
# Rows: 3770
#       Source                                      Original_Text  \
# 0  rcm.ac.in    Copyright © 2026 Regional College Of Management
# 1  rcm.ac.in  Home > blogs > ugc act 2026 > What is UGC Act ...
# 2  rcm.ac.in  The UGC Act 2026 has become one of the most di...
# 3  rcm.ac.in  Let’s break down the UGC meaning, UGC law, UGC...
# 4  rcm.ac.in  The term UGC Act 2026 refers to the University...
#
#                                      Translated_Text Language  \
# 0    Copyright © 2026 Regional College Of Management       en
# 1  Home > blogs > ugc act 2026 > What is UGC Act ...       en
# 2  The UGC Act 2026 has become one of the most di...       en
# 3  Let’s break down the UGC meaning, UGC law, UGC...       en
# 4  The term UGC Act 2026 refers to the University...       en
#
#                                        URL
# 0  https://rcm.ac.in/what-is-ugc-act-2026/
# 1  https://rcm.ac.in/what-is-ugc-act-2026/
# 2  https://rcm.ac.in/what-is-ugc-act-2026/
# ...

# %%
df['Text'] = df['Translated_Text']

# %%
stop_words = set(stopwords.words('english'))

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'[^a-z\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()

    words = text.split()
    words = [w for w in words if w not in stop_words and len(w) > 2]

    return " ".join(words)

df['Clean_Text'] = df['Text'].apply(clean_text)

# %%
sia = SentimentIntensityAnalyzer()

def get_sentiment(text):
    score = sia.polarity_scores(text)['compound']

    if score >= 0.1:
        return "positive"
    elif score <= -0.1:
        return "negative"
    else:
        return "neutral"

df['Sentiment'] = df['Clean_Text'].apply(get_sentiment)

print(df['Sentiment'].value_counts())
# Out:
# Sentiment
# positive    1582
# negative    1279
# neutral      909
# Name: count, dtype: int64

# %%
vectorizer = TfidfVectorizer(
    max_features=12000,
    ngram_range=(1,3),
    min_df=2,
    max_df=0.9,
    sublinear_tf=True
)

X = vectorizer.fit_transform(df['Clean_Text'])
y = df['Sentiment']

# %%
ros = RandomOverSampler(random_state=42)

X_resampled, y_resampled = ros.fit_resample(X, y)

print(pd.Series(y_resampled).value_counts())
# Out:
# Sentiment
# neutral     1582
# positive    1582
# negative    1582
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_resampled, y_resampled,
    test_size=0.2,
    random_state=42
)

# %%
from sklearn.svm import LinearSVC

model = LinearSVC()
model.fit(X_train, y_train)
# Out:
# LinearSVC()

# %%
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.783157894736842
#
# Classification Report:
#                precision    recall  f1-score   support
#
#     negative       0.80      0.76      0.78       330
#      neutral       0.76      0.84      0.80       306
#     positive       0.79      0.75      0.77       314
#
#     accuracy                           0.78       950
#    macro avg       0.78      0.78      0.78       950
# weighted avg       0.78      0.78      0.78       950

# %%
# Vectorization
vectorizer = TfidfVectorizer(
    max_features=15000,
    ngram_range=(1,3),
    min_df=3,
    max_df=0.85,
    sublinear_tf=True
)

X = vectorizer.fit_transform(df['Clean_Text'])
y = df['Sentiment']

# Balance
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler()
X_resampled, y_resampled = ros.fit_resample(X, y)

# Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X_resampled, y_resampled, test_size=0.2, random_state=42
)

# Model
from sklearn.svm import LinearSVC
model = LinearSVC(C=1.5, class_weight='balanced')
model.fit(X_train, y_train)

# Evaluation
from sklearn.metrics import accuracy_score
print("Accuracy:", accuracy_score(y_test, model.predict(X_test)))
# Out:
# Accuracy: 0.7926315789473685

# %% [markdown]
# previous without translation

# %%
def scrape_article(url):

    headers = {
        "User-Agent": "Mozilla/5.0"
    }

    try:
        response = requests.get(url, headers=headers, timeout=10)

        if response.status_code != 200:
            print("Failed to fetch:", url)
            return []

        soup = BeautifulSoup(response.text, "html.parser")

        rows = []

        # Extract all paragraphs
        for p in soup.find_all("p"):
            text = p.get_text().strip()

            # Filter unwanted small text
            if len(text) > 40:

                rows.append({
                    "Source": url.split("/")[2],
                    "Text": text,
                    "URL": url
                })

        return rows

    except Exception as e:
        print("Error in:", url, e)
        return []


dataset = []

for url in urls:

    print("Scraping:", url)

    article_rows = scrape_article(url)

    dataset.extend(article_rows)

    print("Paragraphs extracted:", len(article_rows))

    time.sleep(2)  # avoid blocking



df = pd.DataFrame(dataset)

print("Total Rows:", len(df))
print("Columns:", df.columns)
# Out:
# Scraping: https://www.ugc.gov.in/regulations
# Failed to fetch: https://www.ugc.gov.in/regulations
# Paragraphs extracted: 0
# Scraping: https://rcm.ac.in/what-is-ugc-act-2026/
# Paragraphs extracted: 43
# Scraping: https://www.pmfias.com/ugc-anti-discrimination-regulations/
# Paragraphs extracted: 9
# Scraping: https://indianexpress.com/article/explained/ugc-new-regulation-controversy-10496730/
# Paragraphs extracted: 35
# Scraping: https://indianexpress.com/article/explained/ugc-equity-guidelines-2012-2026-10502081/
# Paragraphs extracted: 24
# Scraping: https://www.newindianexpress.com/nation/2026/Jan/29/explainer-how-the-new-ugc-equity-regulations-reshape-campus-anti-discrimination-rules
# Paragraphs extracted: 13
# Scraping: https://www.livelaw.in/articles/ugc-regulations-2026-examining-equity-522470
# Paragraphs extracted: 32
# ...

# %%
df.head()        # first rows
df.sample(5)     # random rows
# Out:
#                             Source  \
# 624               www.thehindu.com
# 2043              www.tv9hindi.com
# 1090         www.bhaskarenglish.in
# 1532  english.dainikjagranmpcg.com
# 1659            www.jagranjosh.com
#
#                                                    Text  \
# 624   The University Grants Commission (Promotion of...
# 2043  रॉलेट एक्ट को अंग्रेजों ने मार्च 1919 में लाया...
# 1090  Complaint procedure: Equity Committees must ac...
# 1532  Q3: What happens if a college does not comply ...
# 1659  JEE Main 2026 LIVE: Session 2 Admit Card Expec...
#
#                                                     URL
# 624   https://www.thehindu.com/education/why-have-th...
# 2043  https://www.tv9hindi.com/india/bareilly-city-m...
# 1090  https://www.bhaskarenglish.in/originals/news/u...
# 1532  https://english.dainikjagranmpcg.com/education...
# 1659  https://www.jagranjosh.com/general-knowledge/u...

# %%
df.to_csv("ugc_paragraph_dataset.csv", index=False)

print("Dataset saved successfully!")
# Out:
# Dataset saved successfully!

# %%
import re
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

def clean_text(text):

    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)   # remove punctuation & numbers

    words = text.split()
    words = [word for word in words if word not in stop_words]

    return " ".join(words)

df['Clean_Text'] = df['Text'].apply(clean_text)

df.head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#       Source                                               Text  \
# 0  rcm.ac.in    Copyright © 2026 Regional College Of Management
# 1  rcm.ac.in  Home > blogs > ugc act 2026 > What is UGC Act ...
# 2  rcm.ac.in  The UGC Act 2026 has become one of the most di...
# 3  rcm.ac.in  Let’s break down the UGC meaning, UGC law, UGC...
# 4  rcm.ac.in  The term UGC Act 2026 refers to the University...
#
#                                        URL  \
# 0  https://rcm.ac.in/what-is-ugc-act-2026/
# 1  https://rcm.ac.in/what-is-ugc-act-2026/
# 2  https://rcm.ac.in/what-is-ugc-act-2026/
# 3  https://rcm.ac.in/what-is-ugc-act-2026/
# 4  https://rcm.ac.in/what-is-ugc-act-2026/
#
#                                           Clean_Text
# 0              copyright regional college management
# 1  home blogs ugc act ugc act new ugc rules bill ...
# ...

# %%
df.to_csv('ugc_cleaned_dataset.csv', index=False)
print("Cleaned dataset saved successfully")
# Out:
# Cleaned dataset saved successfully

# %%
from nltk.tokenize import word_tokenize
nltk.download('punkt_tab')

df['Tokens'] = df['Clean_Text'].apply(word_tokenize)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')

sia = SentimentIntensityAnalyzer()

def get_sentiment(text):

    score = sia.polarity_scores(text)['compound']

    if score >= 0.05:
        return "positive"
    elif score <= -0.05:
        return "negative"
    else:
        return "neutral"

df['Sentiment'] = df['Clean_Text'].apply(get_sentiment)

df.head()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
#       Source                                               Text  \
# 0  rcm.ac.in    Copyright © 2026 Regional College Of Management
# 1  rcm.ac.in  Home > blogs > ugc act 2026 > What is UGC Act ...
# 2  rcm.ac.in  The UGC Act 2026 has become one of the most di...
# 3  rcm.ac.in  Let’s break down the UGC meaning, UGC law, UGC...
# 4  rcm.ac.in  The term UGC Act 2026 refers to the University...
#
#                                        URL  \
# 0  https://rcm.ac.in/what-is-ugc-act-2026/
# 1  https://rcm.ac.in/what-is-ugc-act-2026/
# 2  https://rcm.ac.in/what-is-ugc-act-2026/
# 3  https://rcm.ac.in/what-is-ugc-act-2026/
# 4  https://rcm.ac.in/what-is-ugc-act-2026/
#
#                                           Clean_Text  \
# 0              copyright regional college management
# 1  home blogs ugc act ugc act new ugc rules bill ...
# 2  ugc act become one discussed education reforms...
# ...

# %%
print(df['Sentiment'].value_counts())
# Out:
# Sentiment
# neutral     838
# positive    767
# negative    504
# Name: count, dtype: int64

# %%
df.to_csv('ugc_cleaned_sentiment_dataset.csv', index=False)
print("Cleaned dataset saved successfully")
# Out:
# Cleaned dataset with sentiment saved successfully as ugc_cleaned_sentiment_dataset.csv

# %%
# !pip install nltk scikit-learn imbalanced-learn

import pandas as pd
import re
import nltk
nltk.download('stopwords')
nltk.download('vader_lexicon')

from nltk.corpus import stopwords
from nltk.sentiment import SentimentIntensityAnalyzer

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

from imblearn.over_sampling import RandomOverSampler
# Out:
# ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
stop_words = set(stopwords.words('english'))

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', ' ', text)   # remove punctuation
    text = re.sub(r'\s+', ' ', text).strip()

    words = text.split()
    words = [w for w in words if w not in stop_words and len(w) > 2]

    return " ".join(words)

df['Clean_Text'] = df['Text'].apply(clean_text)

# %%
sia = SentimentIntensityAnalyzer()

def get_sentiment(text):
    score = sia.polarity_scores(text)['compound']

    if score >= 0.1:
        return "positive"
    elif score <= -0.1:
        return "negative"
    else:
        return "neutral"

df['Sentiment'] = df['Clean_Text'].apply(get_sentiment)

print(df['Sentiment'].value_counts())
# Out:
# Sentiment
# neutral     871
# positive    736
# negative    502
# Name: count, dtype: int64

# %%
vectorizer = TfidfVectorizer(
    max_features=8000,
    ngram_range=(1,2),   # uni + bi-grams
    min_df=2
)

X = vectorizer.fit_transform(df['Clean_Text'])
y = df['Sentiment']

# %%
ros = RandomOverSampler(random_state=42)

X_resampled, y_resampled = ros.fit_resample(X, y)

print("After balancing:")
print(pd.Series(y_resampled).value_counts())
# Out:
# After balancing:
# Sentiment
# neutral     871
# positive    871
# negative    871
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_resampled, y_resampled,
    test_size=0.2,
    random_state=42
)

# %%
model = LogisticRegression(
    max_iter=300,
    class_weight='balanced'
)

model.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=300)

# %%
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8432122370936902
#
# Classification Report:
#                precision    recall  f1-score   support
#
#     negative       0.82      0.90      0.86       158
#      neutral       0.84      0.89      0.86       176
#     positive       0.88      0.75      0.81       189
#
#     accuracy                           0.84       523
#    macro avg       0.84      0.85      0.84       523
# weighted avg       0.85      0.84      0.84       523

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cm = confusion_matrix(y_test, y_pred)

plt.figure()
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
#import pickle

#pickle.dump(model, open("sentiment_model.pkl", "wb"))
#pickle.dump(vectorizer, open("tfidf_vectorizer.pkl", "wb"))

#print("Model saved successfully!")
